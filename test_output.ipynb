# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

# %%
df.head(100)
# Out:
#                                               Address  \
# 0                                Heisterbergallee 10A
# 1                                   Via Dei Villini 4
# 2                                        Marconiweg 5
# 3                                          7 사곡1리지현 길
# 4                                      11 Hughes Cres
# ..                                                ...
# 95                                 Meulebekestraat 57
# 96  Avenida Governador Leonel De Moura Brizola,  2973
# 97                                      Via Emilia 17
# 98                                  Heer-weg Zuid 124
# 99                               Karl-Marx-straße 120
#
#                                     STREET_NAME  HOUSE_NO   SUITE_NO
# 0                              Heisterbergallee       10A        NaN
# 1                               Via Dei Villini         4        NaN
# 2                                    Marconiweg         5        NaN
# ...

# %%
df.sample(50)
# Out:
#                                        Address  \
# 70734                             Dzwonkowa 14
# 50240                           Skelhøjevej 11
# 1082                             19 Sun Street
# 69273                            Vesterveien 1
# 42380                54 Rue Du Général Leclerc
# 76783                          徳島県 東沖洲 １丁目 １ 5
# 8339                      Steinackerstrasse 35
# 67068                       31 대왕판교로606번 길 삼평동
# 117161                     Rue Laurent Gilys 8
# 54518                            80 청수14 로 청당동
# 93089                              2 Rue Hallé
# 81964                  José Miguel Carrera 725
# 120517                 Neidensteiner Straße 32
# 117241                             372 경부 고속도로
# 18932                               Hohlweg 18
# 109112      Avenida João Naves De Ávila,  1331
# 76896                           22 School Road
# 11050                      Johannes-Rau-weg 10
# 108159                          129 Beach Road
# ...

# %%
df_train = pd.read_csv('ver-2023-01_train_output.csv')

# %%
df_train.head()
# Out:
#                           NAME          ADDRESS  STREET_NAME HOUSE_NO  \
# 0  REGINA GEN HOSP RECVNG DOCK    1440 14TH AVE     14TH AVE     1440
# 1  ATHOL MURRAY COLLEGE SODEXO       49 MAIN ST      MAIN ST       49
# 2           EXTENDICARE SUNSET    260 SUNSET DR    SUNSET DR      260
# 3           EXTENDICARE SUNSET    260 SUNSET DR    SUNSET DR      260
# 4                 BOSTON PIZZA  545 N ALBERT ST  N ALBERT ST      545
#
#   SUITE_NO    CITY REGION   POSTAL COUNTRY                   NAME_RIGHT  \
# 0      NaN  REGINA     SK  S4P 0W5     CAN  MALTY NATIONAL BREWING CORP
# 1      NaN  WILCOX     SK  S0G 5E0     CAN   COLLEGE OF NOTRE DAME CAFE
# 2      NaN  REGINA     SK  S4S 2S3     CAN         EXTENDICARE PARKSIDE
# 3      NaN  REGINA     SK  S4S 2S3     CAN          EXTENDICARE ELMVIEW
# 4      NaN  REGINA     SK  S4R 8E2     CAN                WESTO'S PIZZA
#
#               ADDRESS_RIGHT     STREET_NAME_RIGHT HOUSE_NO_RIGHT  \
# ...

# %%
df_test = pd.read_csv('ver-2023-01_test_output.csv')

# %%
df_test.head()
# Out:
#                              NAME                         ADDRESS  \
# 0              PIZZA HUT ELDORADO        AVENIDA REBOUÇAS, 3970
# 1                           MOE'S           1326 TOWN CENTER DR
# 2                      IBIS HOTEL                    MOUNT TALBOT
# 3          RVR ENTERPRISES RAIPUR      SHARMA COMPLEX SHOP NO 4
# 4  ROYAL ORTHOPAEDIC HOSPITAL NHS  BRISTOL ROAD SOUTH  NORTHFIELD
#
#                      STREET_NAME HOUSE_NO SUITE_NO        CITY       REGION  \
# 0              AVENIDA REBOUÇAS,     3970      NaN   SÃO PAULO           SP
# 1                 TOWN CENTER DR     1326      NaN    LAKELAND           FL
# 2                   MOUNT TALBOT      NaN      NaN   DUBLIN 22           DB
# 3         SHARMA COMPLEX SHOP NO      NaN        4      RAIPUR  CHATTISGARH
# 4  BRISTOL ROAD SOUTH NORTHFIELD      NaN      NaN  BIRMINGHAM           WM
#
#        POSTAL COUNTRY                      NAME_RIGHT  \
# 0   05402-600     BRA              PIZZA HUT ELDORADO
# ...
